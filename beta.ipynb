# %%
beta11 <- rbeta(100000,1,1)
hist(beta11)
# Out:
# Plot with title “Histogram of beta11”

# %%
beta41 <- rbeta(100000,4,1)
hist(beta41)
# Out:
# Plot with title “Histogram of beta41”

# %%
beta55 <- rbeta(100000,5,5)
hist(beta55)
# Out:
# Plot with title “Histogram of beta55”

# %%
beta100100 <- rbeta(100000,100,100)
hist(beta100100)
# Out:
# Plot with title “Histogram of beta100100”

# %%
beta53 <- rbeta(100000,5,3)
hist(beta53)
# Out:
# Plot with title “Histogram of beta53”

# %%
beta35 <- rbeta(100000,3,5)
hist(beta35)
# Out:
# Plot with title “Histogram of beta35”

# %%
beta0505 <- rbeta(100000,0.5,0.5)
hist(beta0505)
# Out:
# Plot with title “Histogram of beta0505”
